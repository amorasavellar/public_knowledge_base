# %%
import requests

# %% [markdown]
# https://docs.github.com/en

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# # Explorando a biblioteca

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.text
# Out:
# '[{"id":"32933169881","type":"PushEvent","actor":{"id":8103683,"login":"zirklbch","display_login":"zirklbch","gravatar_id":"","url":"https://api.github.com/users/zirklbch","avatar_url":"https://avatars.githubusercontent.com/u/8103683?"},"repo":{"id":620009127,"name":"zirklbch/zirklbch.github.io","url":"https://api.github.com/repos/zirklbch/zirklbch.github.io"},"payload":{"repository_id":620009127,"push_id":15612675513,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"cf4fe45046ee0eb344c390137d64b5438673fce7","before":"cb242384a65ff1d92d3eaa0b148884963d04581d","commits":[{"sha":"cf4fe45046ee0eb344c390137d64b5438673fce7","author":{"email":"james.zirkelbach@gmail.com","name":"zirklbch"},"message":"Automated Metra GTFS feed updates","distinct":true,"url":"https://api.github.com/repos/zirklbch/zirklbch.github.io/commits/cf4fe45046ee0eb344c390137d64b5438673fce7"}]},"public":true,"created_at":"2023-10-30T00:10:05Z"},{"id":"32933169877","type":"PullRequestEvent","actor":{"id":28595571,"login":"wwtche","display_login":"wwtche","gravatar_id":"","url":"https://api.github.com/users/wwtche","avatar_url":"https://avatars.githubusercontent.com/u/28595571?"},"repo":{"id":711581616,"name":"wwtche/security-operations-task","url":"https://api.github.com/repos/wwtche/security-operations-task"},"payload":{"action":"opened","number":10,"pull_request":{"url":"https://api.github.com/repos/wwtche/security-operations-task/pulls/10","id":1578061632,"node_id":"PR_kwDOKmnfsM5eD09A","html_url":"https://github.com/wwtche/security-operations-task/pull/10","diff_url":"https://github.com/wwtche/security-operations-task/pull/10.diff","patch_url":"https://github.com/wwtche/security-operations-task/pull/10.patch","issue_url":"https://api.github.com/repos/wwtche/security-operations-task/issues/10","number":10,"state":"open","locked":false,"title":"new dockerfile for rates api","user":{"login":"wwtche","id":28595571,"node_id":"MDQ6VXNlcjI4NTk1NTcx","avatar_url":"https://avatars.githubusercontent.com/u/28595571?v=4","gravatar_id":"","url":"https://api.github.com/users/wwtche","html_url":"https://github.com/wwtche","followers_url":"https://api.github.com/users/wwtche/followers","following_url":"https://api.github.com/users/wwtche/following{/other_user}","gists_url":"https://api.github.com/users/wwtche/gists{/gist_id}","starred_url":"https://api.github.com/users/wwtche/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/wwtche/subscriptions","organizations_url":"https://api.github.com/users/wwtche/orgs","repos_url":"https://api.github.com/users/wwtche/repos","events_url":"https://api.github.com/users/wwtche/events{/privacy}","received_events_url":"https://api.github.com/users/wwtche/received_events","type":"User","site_admin":false},"body":null,"created_at":"2023-10-30T00:10:04Z","updated_at":"2023-10-30T00:10:04Z","closed_at":null,"merged_at":null,"merge_commit_sha":null,"assignee":null,"assignees":[],"requested_reviewers":[],"requested_teams":[],"labels":[],"milestone":null,"draft":false,"commits_url":"https://api.github.com/repos/wwtche/security-operations-task/pulls/10/commits","review_comments_url":"https://api.github.com/repos/wwtche/security-operations-task/pulls/10/comments","review_comment_url":"https://api.github.com/repos/wwtche/security-operations-task/pulls/comments{/number}","comments_url":"https://api.github.com/repos/wwtche/security-operations-task/issues/10/comments","statuses_url":"https://api.github.com/repos/wwtche/security-operations-task/statuses/1771fdd6e66b1c6ceb8b47d89874f04000c89e8e","head":{"label":"wwtche:dockerise-rates-api","ref":"dockerise-rates-api","sha":"1771fdd6e66b1c6ceb8b47d89874f04000c89e8e","user":{"login":"wwtche","id":28595571,"node_id":"MDQ6VXNlcjI4NTk1NTcx","avatar_url":"https://avatars.githubusercontent.com/u/28595571?v=4","gravatar_id":"","url":"https://api.github.com/users/wwtche","html_url":"https://github.com/wwtche","followers_url":"https://api.github.com/users/wwtche/followers","following ...

# %%
r.json()
# Out:
# [{'id': '32933169881',
#   'type': 'PushEvent',
#   'actor': {'id': 8103683,
#    'login': 'zirklbch',
#    'display_login': 'zirklbch',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zirklbch',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8103683?'},
#   'repo': {'id': 620009127,
#    'name': 'zirklbch/zirklbch.github.io',
#    'url': 'https://api.github.com/repos/zirklbch/zirklbch.github.io'},
#   'payload': {'repository_id': 620009127,
#    'push_id': 15612675513,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'cf4fe45046ee0eb344c390137d64b5438673fce7',
#    'before': 'cb242384a65ff1d92d3eaa0b148884963d04581d',
#    'commits': [{'sha': 'cf4fe45046ee0eb344c390137d64b5438673fce7',
#      'author': {'email': 'james.zirkelbach@gmail.com', 'name': 'zirklbch'},
#      'message': 'Automated Metra GTFS feed updates',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/zirklbch/zirklbch.github.io/commits/cf4fe45046ee0eb344c390137d64b5438673fce7'}]},
#   'public': True,
#   'created_at': '2023-10-30T00:10:05Z'},
#  {'id': '32933169877',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 28595571,
#    'login': 'wwtche',
#    'display_login': 'wwtche',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wwtche',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28595571?'},
#   'repo': {'id': 711581616,
#    'name': 'wwtche/security-operations-task',
#    'url': 'https://api.github.com/repos/wwtche/security-operations-task'},
#   'payload': {'action': 'opened',
#    'number': 10,
#    'pull_request': {'url': 'https://api.github.com/repos/wwtche/security-operations-task/pulls/10',
#     'id': 1578061632,
#     'node_id': 'PR_kwDOKmnfsM5eD09A',
#     'html_url': 'https://github.com/wwtche/security-operations-task/pull/10',
#     'diff_url': 'https://github.com/wwtche/security-operations-task/pull/10.diff',
#     'patch_url': 'https://github.com/wwtche/security-operations-task/pull/10.patch',
#     'issue_url': 'https://api.github.com/repos/wwtche/security-operations-task/issues/10',
#     'number': 10,
#     'state': 'open',
#     'locked': False,
#     'title': 'new dockerfile for rates api',
#     'user': {'login': 'wwtche',
#      'id': 28595571,
#      'node_id': 'MDQ6VXNlcjI4NTk1NTcx',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/28595571?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/wwtche',
#      'html_url': 'https://github.com/wwtche',
#      'followers_url': 'https://api.github.com/users/wwtche/followers',
#      'following_url': 'https://api.github.com/users/wwtche/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/wwtche/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/wwtche/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/wwtche/subscriptions',
#      'organizations_url': 'https://api.github.com/users/wwtche/orgs',
#      'repos_url': 'https://api.github.com/users/wwtche/repos',
#      'events_url': 'https://api.github.com/users/wwtche/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/wwtche/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2023-10-30T00:10:04Z',
#     'updated_at': '2023-10-30T00:10:04Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/wwtche/security-operations-task/pulls/10/commits',
#     'review_comments_url': 'https://api.github.com/repos/wwtche/security-operations-task/pulls/10/comments',
#     'review_comment_url': 'https://api.github.com/repos/wwtche/security-operations-task/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/wwtche/security-operations-task/issues/10/comments',
#     'statuses_url': 'https://api.github.com/repos/wwtche/security-operations-task/statuses/1771fdd6e66b1c6ceb8b47d89874f04000c89e8e',
#     'head': {'label': 'wwtche:dockerise-rates-api',
#      'ref': 'dockerise-rates-api',
#      'sha': '1771fdd6e66b1c6ceb8b47d89874f04000c89e8e',
#      'user': {'login': 'wwtche',
#       'id': 28595571,
#       'node_id': 'MDQ6VXNlcjI4NTk1NTcx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/28595571?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/wwtche',
#       'html_url': 'https://github.com/wwtche',
#       'followers_url': 'https://api.github.com/users/wwtche/followers',
#       'following_url': 'https://api.github.com/users/wwtche/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/wwtche/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/wwtche/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/wwtche/subscriptions',
#       'organizations_url': 'https://api.github.com/users/wwtche/orgs',
#       'repos_url': 'https://api.github.com/users/wwtche/repos',
#       'events_url': 'https://api.github.com/users/wwtche/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/wwtche/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 711581616,
#       'node_id': 'R_kgDOKmnfsA',
#       'name': 'security-operations-task',
#       'full_name': 'wwtche/security-operations-task',
#       'private': False,
#       'owner': {'login': 'wwtche',
#        'id': 28595571,
#        'node_id': 'MDQ6VXNlcjI4NTk1NTcx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/28595571?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/wwtche',
#        'html_url': 'https://github.com/wwtche',
#        'followers_url': 'https://api.github.com/users/wwtche/followers',
#        'following_url': 'https://api.github.com/users/wwtche/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/wwtche/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/wwtche/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/wwtche/subscriptions',
#        'organizations_url': 'https://api.github.com/users/wwtche/orgs',
#        'repos_url': 'https://api.github.com/users/wwtche/repos',
#        'events_url': 'https://api.github.com/users/wwtche/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/wwtche/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/wwtche/security-operations-task',
#       'description': None,
#       'fork': True,
#       'url': 'https://api.github.com/repos/wwtche/security-operations-task',
#       'forks_url': 'https://api.github.com/repos/wwtche/security-operations-task/forks',
#       'keys_url': 'https://api.github.com/repos/wwtche/security-operations-task/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/wwtche/security-operations-task/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/wwtche/security-operations-task/teams',
#       'hooks_url': 'https://api.github.com/repos/wwtche/security-operations-task/hooks',
#       'issue_events_url': 'https://api.github.com/repos/wwtche/security-operations-task/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/wwtche/security-operations-task/events',
#       'assignees_url': 'https://api.github.com/repos/wwtche/security-operations-task/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/wwtche/security-operations-task/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/wwtche/security-operations-task/tags',
#       'blobs_url': 'https://api.github.com/repos/wwtche/security-operations-task/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/wwtche/security-operations-task/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/wwtche/security-operations-task/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/wwtche/security-operations-task/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/wwtche/security-operations-task/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/wwtche/security-operations-task/languages',
#       'stargazers_url': 'https://api.github.com/repos/wwtche/security-operations-task/stargazers',
#       'contributors_url': 'https://api.github.com/repos/wwtche/security-operations-task/contributors',
#       'subscribers_url': 'https://api.github.com/repos/wwtche/security-operations-task/subscribers',
#       'subscription_url': 'https://api.github.com/repos/wwtche/security-operations-task/subscription',
#       'commits_url': 'https://api.github.com/repos/wwtche/security-operations-task/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/wwtche/security-operations-task/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/wwtche/security-operations-task/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/wwtche/security-operations-task/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/wwtche/security-operations-task/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/wwtche/security-operations-task/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/wwtche/security-operations-task/merges',
#       'archive_url': 'https://api.github.com/repos/wwtche/security-operations-task/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/wwtche/security-operations-task/downloads',
#       'issues_url': 'https://api.github.com/repos/wwtche/security-operations-task/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/wwtche/security-operations-task/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/wwtche/security-operations-task/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/wwtche/security-operations-task/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/wwtche/security-operations-task/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/wwtche/security-operations-task/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/wwtche/security-operations-task/deployments',
#       'created_at': '2023-10-29T17:45:34Z',
#       'updated_at': '2023-10-29T17:46:48Z',
#       'pushed_at': '2023-10-30T00:10:05Z',
#       'git_url': 'git://github.com/wwtche/security-operations-task.git',
#       'ssh_url': 'git@github.com:wwtche/security-operations-task.git',
#       'clone_url': 'https://github.com/wwtche/security-operations-task.git',
#       'svn_url': 'https://github.com/wwtche/security-operations-task',
#       'homepage': None,
#       'size': 193,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Python',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'wwtche:main',
#      'ref': 'main',
#      'sha': 'e1d7e7d2a7d7516817dbc3b9e35cc4cf3cbcedff',
#      'user': {'login': 'wwtche',
#       'id': 28595571,
#       'node_id': 'MDQ6VXNlcjI4NTk1NTcx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/28595571?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/wwtche',
#       'html_url': 'https://github.com/wwtche',
#       'followers_url': 'https://api.github.com/users/wwtche/followers',
#       'following_url': 'https://api.github.com/users/wwtche/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/wwtche/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/wwtche/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/wwtche/subscriptions',
#       'organizations_url': 'https://api.github.com/users/wwtche/orgs',
#       'repos_url': 'https://api.github.com/users/wwtche/repos',
#       'events_url': 'https://api.github.com/users/wwtche/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/wwtche/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 711581616,
#       'node_id': 'R_kgDOKmnfsA',
#       'name': 'security-operations-task',
#       'full_name': 'wwtche/security-operations-task',
#       'private': False,
#       'owner': {'login': 'wwtche',
#        'id': 28595571,
#        'node_id': 'MDQ6VXNlcjI4NTk1NTcx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/28595571?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/wwtche',
#        'html_url': 'https://github.com/wwtche',
#        'followers_url': 'https://api.github.com/users/wwtche/followers',
#        'following_url': 'https://api.github.com/users/wwtche/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/wwtche/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/wwtche/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/wwtche/subscriptions',
#        'organizations_url': 'https://api.github.com/users/wwtche/orgs',
#        'repos_url': 'https://api.github.com/users/wwtche/repos',
#        'events_url': 'https://api.github.com/users/wwtche/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/wwtche/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/wwtche/security-operations-task',
#       'description': None,
#       'fork': True,
#       'url': 'https://api.github.com/repos/wwtche/security-operations-task',
#       'forks_url': 'https://api.github.com/repos/wwtche/security-operations-task/forks',
#       'keys_url': 'https://api.github.com/repos/wwtche/security-operations-task/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/wwtche/security-operations-task/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/wwtche/security-operations-task/teams',
#       'hooks_url': 'https://api.github.com/repos/wwtche/security-operations-task/hooks',
#       'issue_events_url': 'https://api.github.com/repos/wwtche/security-operations-task/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/wwtche/security-operations-task/events',
#       'assignees_url': 'https://api.github.com/repos/wwtche/security-operations-task/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/wwtche/security-operations-task/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/wwtche/security-operations-task/tags',
#       'blobs_url': 'https://api.github.com/repos/wwtche/security-operations-task/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/wwtche/security-operations-task/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/wwtche/security-operations-task/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/wwtche/security-operations-task/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/wwtche/security-operations-task/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/wwtche/security-operations-task/languages',
#       'stargazers_url': 'https://api.github.com/repos/wwtche/security-operations-task/stargazers',
#       'contributors_url': 'https://api.github.com/repos/wwtche/security-operations-task/contributors',
#       'subscribers_url': 'https://api.github.com/repos/wwtche/security-operations-task/subscribers',
#       'subscription_url': 'https://api.github.com/repos/wwtche/security-operations-task/subscription',
#       'commits_url': 'https://api.github.com/repos/wwtche/security-operations-task/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/wwtche/security-operations-task/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/wwtche/security-operations-task/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/wwtche/security-operations-task/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/wwtche/security-operations-task/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/wwtche/security-operations-task/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/wwtche/security-operations-task/merges',
#       'archive_url': 'https://api.github.com/repos/wwtche/security-operations-task/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/wwtche/security-operations-task/downloads',
#       'issues_url': 'https://api.github.com/repos/wwtche/security-operations-task/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/wwtche/security-operations-task/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/wwtche/security-operations-task/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/wwtche/security-operations-task/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/wwtche/security-operations-task/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/wwtche/security-operations-task/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/wwtche/security-operations-task/deployments',
#       'created_at': '2023-10-29T17:45:34Z',
#       'updated_at': '2023-10-29T17:46:48Z',
#       'pushed_at': '2023-10-30T00:10:05Z',
#       'git_url': 'git://github.com/wwtche/security-operations-task.git',
#       'ssh_url': 'git@github.com:wwtche/security-operations-task.git',
#       'clone_url': 'https://github.com/wwtche/security-operations-task.git',
#       'svn_url': 'https://github.com/wwtche/security-operations-task',
#       'homepage': None,
#       'size': 193,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Python',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/wwtche/security-operations-task/pulls/10'},
#      'html': {'href': 'https://github.com/wwtche/security-operations-task/pull/10'},
#      'issue': {'href': 'https://api.github.com/repos/wwtche/security-operations-task/issues/10'},
#      'comments': {'href': 'https://api.github.com/repos/wwtche/security-operations-task/issues/10/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/wwtche/security-operations-task/pulls/10/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/wwtche/security-operations-task/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/wwtche/security-operations-task/pulls/10/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/wwtche/security-operations-task/statuses/1771fdd6e66b1c6ceb8b47d89874f04000c89e8e'}},
#     'author_association': 'OWNER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 47,
#     'deletions': 0,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2023-10-30T00:10:05Z'},
#  {'id': '32933169823',
#   'type': 'PushEvent',
#   'actor': {'id': 148814961,
#    'login': 'kaibailey2',
#    'display_login': 'kaibailey2',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kaibailey2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/148814961?'},
#   'repo': {'id': 710951996,
#    'name': 'kaibailey2/info201Final',
#    'url': 'https://api.github.com/repos/kaibailey2/info201Final'},
#   'payload': {'repository_id': 710951996,
#    'push_id': 15612675477,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '2f377cfed65dd06e7e7dedca7102b4bd6bbc2dbe',
#    'before': 'd36a9994f7d9ced30c443f354a066b0a80ccde9d',
#    'commits': [{'sha': '2f377cfed65dd06e7e7dedca7102b4bd6bbc2dbe',
#      'author': {'email': '148814961+kaibailey2@users.noreply.github.com',
#       'name': 'kaibailey2'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kaibailey2/info201Final/commits/2f377cfed65dd06e7e7dedca7102b4bd6bbc2dbe'}]},
#   'public': True,
#   'created_at': '2023-10-30T00:10:05Z'},
#  {'id': '32933169852',
#   'type': 'PushEvent',
#   'actor': {'id': 115139640,
#    'login': 'freecall2019',
#    'display_login': 'freecall2019',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/freecall2019',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/115139640?'},
#   'repo': {'id': 662012950,
#    'name': 'freecall2019/day',
#    'url': 'https://api.github.com/repos/freecall2019/day'},
#   'payload': {'repository_id': 662012950,
#    'push_id': 15612675495,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '225af6fb902e49f579bdfd71aa5081a9b4d6df77',
#    'before': '4b88c3d649544f340bf04e9a2cd51de146c8114f',
#    'commits': [{'sha': '225af6fb902e49f579bdfd71aa5081a9b4d6df77',
#      'author': {'email': '115139640+freecall2019@users.noreply.github.com',
#       'name': 'freecall'},
#      'message': 'super',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/freecall2019/day/commits/225af6fb902e49f579bdfd71aa5081a9b4d6df77'}]},
#   'public': True,
#   'created_at': '2023-10-30T00:10:05Z'},
#  {'id': '32933169832',
#   'type': 'PushEvent',
#   'actor': {'id': 6033525,
#    'login': 'krot4u',
#    'display_login': 'krot4u',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/krot4u',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6033525?'},
#   'repo': {'id': 595123203,
#    'name': 'krot4u/Public_scripts',
#    'url': 'https://api.github.com/repos/krot4u/Public_scripts'},
#   'payload': {'repository_id': 595123203,
#    'push_id': 15612675466,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '629661e3022f08bd4dd699434b25592b50e60dde',
#    'before': 'f5935d503c52866a938b0adc17d4d1ed416a9659',
#    'commits': [{'sha': '629661e3022f08bd4dd699434b25592b50e60dde',
#      'author': {'email': 'krot4u@gmail.com', 'name': 'krot4u'},
#      'message': 'Update dmrid.dat with new content',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/krot4u/Public_scripts/commits/629661e3022f08bd4dd699434b25592b50e60dde'}]},
#   'public': True,
#   'created_at': '2023-10-30T00:10:05Z'},
#  {'id': '32933169845',
#   'type': 'PushEvent',
#   'actor': {'id': 12746062,
#    'login': 'manuelvelez',
#    'display_login': 'manuelvelez',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/manuelvelez',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12746062?'},
#   'repo': {'id': 608609149,
#    'name': 'manuelvelez/literate-guacamole',
#    'url': 'https://api.github.com/repos/manuelvelez/literate-guacamole'},
#   'payload': {'repository_id': 608609149,
#    'push_id': 15612675483,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'e618e756872090b20bef10f81262d6f03fba4051',
#    'before': '5a484a40d357d9142bd53dc5a4c79d3c1f1a2606',
#    'commits': [{'sha': 'e618e756872090b20bef10f81262d6f03fba4051',
#      'author': {'email': 'manuelvelez@gmail.com',
#       'name': 'Manuel Vélez Martínez'},
#      'message': 'new commit in 202310/FILE',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/manuelvelez/literate-guacamole/commits/e618e756872090b20bef10f81262d6f03fba4051'}]},
#   'public': True,
#   'created_at': '2023-10-30T00:10:05Z'},
#  {'id': '32933169812',
#   'type': 'PushEvent',
#   'actor': {'id': 77333988,
#    'login': 'Guillei',
#    'display_login': 'Guillei',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Guillei',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/77333988?'},
#   'repo': {'id': 702118866,
#    'name': 'Guillei/tu',
#    'url': 'https://api.github.com/repos/Guillei/tu'},
#   'payload': {'repository_id': 702118866,
#    'push_id': 15612675469,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '464198f3deec7068330df6be2efe48b0a5c45957',
#    'before': '438f482ac650e1133eaa0b14bbfc7d25cf5866fb',
#    'commits': [{'sha': '464198f3deec7068330df6be2efe48b0a5c45957',
#      'author': {'email': '77333988+Guillei@users.noreply.github.com',
#       'name': 'Guillei'},
#      'message': 'Upload screenshot',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Guillei/tu/commits/464198f3deec7068330df6be2efe48b0a5c45957'}]},
#   'public': True,
#   'created_at': '2023-10-30T00:10:05Z'},
#  {'id': '32933169838',
#   'type': 'DeleteEvent',
#   'actor': {'id': 29139614,
#    'login': 'renovate[bot]',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#   'repo': {'id': 391573237,
#    'name': 'rxbn/k3s-gitops',
#    'url': 'https://api.github.com/repos/rxbn/k3s-gitops'},
#   'payload': {'ref': 'renovate/renovate-renovate-37.x',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-10-30T00:10:05Z'},
#  {'id': '32933169819',
#   'type': 'CreateEvent',
#   'actor': {'id': 532821,
#    'login': 'Techjar',
#    'display_login': 'Techjar',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Techjar',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/532821?'},
#   'repo': {'id': 707468717,
#    'name': 'Techjar/VivecraftMod',
#    'url': 'https://api.github.com/repos/Techjar/VivecraftMod'},
#   'payload': {'ref': 'action-manifest-locale',
#    'ref_type': 'branch',
#    'master_branch': 'Multiloader-1.20',
#    'description': 'An experimental port of Vivecraft to Forge/Fabric',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-10-30T00:10:05Z'},
#  {'id': '32933169788',
#   'type': 'PushEvent',
#   'actor': {'id': 52668571,
#    'login': 'ebrahimpichka',
#    'display_login': 'ebrahimpichka',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ebrahimpichka',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52668571?'},
#   'repo': {'id': 529445367,
#    'name': 'ebrahimpichka/ebrahimpichka',
#    'url': 'https://api.github.com/repos/ebrahimpichka/ebrahimpichka'},
#   'payload': {'repository_id': 529445367,
#    'push_id': 15612675449,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ecbf5a538af330a3bd3a329d61193b2c77d96bee',
#    'before': 'dc5138fae4ea059a5a0cad29f052a6ec8bc6e32b',
#    'commits': [{'sha': 'ecbf5a538af330a3bd3a329d61193b2c77d96bee',
#      'author': {'email': 'ebrahim.pichka@gmail.com', 'name': 'Ebrahim Pichka'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ebrahimpichka/ebrahimpichka/commits/ecbf5a538af330a3bd3a329d61193b2c77d96bee'}]},
#   'public': True,
#   'created_at': '2023-10-30T00:10:05Z'},
#  {'id': '32933169782',
#   'type': 'PushEvent',
#   'actor': {'id': 68694120,
#    'login': 'KubaBoi',
#    'display_login': 'KubaBoi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/KubaBoi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/68694120?'},
#   'repo': {'id': 585302040,
#    'name': 'KubaBoi/ntk',
#    'url': 'https://api.github.com/repos/KubaBoi/ntk'},
#   'payload': {'repository_id': 585302040,
#    'push_id': 15612675434,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'c522ff0fbacdada76f0927699418a8b97bc8b916',
#    'before': 'a7f7ce472b55c01def710c05f6e9a02f9e2c701b',
#    'commits': [{'sha': 'c522ff0fbacdada76f0927699418a8b97bc8b916',
#      'author': {'email': 'jakubanderle@outlook.cz', 'name': 'KubaBoi'},
#      'message': " 'Auto Update'",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/KubaBoi/ntk/commits/c522ff0fbacdada76f0927699418a8b97bc8b916'}]},
#   'public': True,
#   'created_at': '2023-10-30T00:10:05Z'},
#  {'id': '32933169805',
#   'type': 'PushEvent',
#   'actor': {'id': 2174564,
#    'login': 'opless',
#    'display_login': 'opless',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/opless',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2174564?'},
#   'repo': {'id': 466088822,
#    'name': 'opless/teefax-mirror',
#    'url': 'https://api.github.com/repos/opless/teefax-mirror'},
#   'payload': {'repository_id': 466088822,
#    'push_id': 15612675457,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd6001701a2b6f8dd831a79f1a5cb5048ab53e775',
#    'before': 'e50a7c1b740a06e16ed4b541d36513dca47c96d6',
#    'commits': [{'sha': 'd6001701a2b6f8dd831a79f1a5cb5048ab53e775',
#      'author': {'email': 'nathan@73d85e00-e7bf-4093-91a5-3d2e11380d6e',
#       'name': 'nathan'},
#      'message': 'Automatic News Update from CIMS indium\n\ngit-svn-id: http://teastop.plus.com/svn/teletext@21524 73d85e00-e7bf-4093-91a5-3d2e11380d6e',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/opless/teefax-mirror/commits/d6001701a2b6f8dd831a79f1a5cb5048ab53e775'}]},
#   'public': True,
#   'created_at': '2023-10-30T00:10:05Z'},
#  {'id': '32933169796',
#   'type': 'PushEvent',
#   'actor': {'id': 25533769,
#    'login': 'oaltawil',
#    'display_login': 'oaltawil',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/oaltawil',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25533769?'},
#   'repo': {'id': 711358563,
#    'name': 'oaltawil/Create-IntuneCustomRole',
#    'url': 'https://api.github.com/repos/oaltawil/Create-IntuneCustomRole'},
#   'payload': {'repository_id': 711358563,
#    'push_id': 15612675451,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '4dac2c7c90e8488595b635fbce56390822bfdff6',
#    'before': '7930c7d672f25a02edd72ccdf5a10a154fd794dc',
#    'commits': [{'sha': '4dac2c7c90e8488595b635fbce56390822bfdff6',
#      'author': {'email': '', 'name': 'Osama Altawil'},
#      'message': 'Added support for simple text file as input.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/oaltawil/Create-IntuneCustomRole/commits/4dac2c7c90e8488595b635fbce56390822bfdff6'}]},
#   'public': True,
#   'created_at': '2023-10-30T00:10:05Z'},
#  {'id': '32933169786',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 620324359,
#    'name': 'GemeenteNijmegen/yivi-issue-server',
#    'url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server'},
#   'payload': {'action': 'closed',
#    'number': 163,
#    'pull_request': {'url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/pulls/163',
#     'id': 1578061251,
#     'node_id': 'PR_kwDOJPlmB85eD03D',
#     'html_url': 'https://github.com/GemeenteNijmegen/yivi-issue-server/pull/163',
#     'diff_url': 'https://github.com/GemeenteNijmegen/yivi-issue-server/pull/163.diff',
#     'patch_url': 'https://github.com/GemeenteNijmegen/yivi-issue-server/pull/163.patch',
#     'issue_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/issues/163',
#     'number': 163,
#     'state': 'closed',
#     'locked': False,
#     'title': 'chore(deps): upgrade dependencies',
#     'user': {'login': 'devops-nijmegen',
#      'id': 136685371,
#      'node_id': 'U_kgDOCCWnOw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/136685371?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/devops-nijmegen',
#      'html_url': 'https://github.com/devops-nijmegen',
#      'followers_url': 'https://api.github.com/users/devops-nijmegen/followers',
#      'following_url': 'https://api.github.com/users/devops-nijmegen/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/devops-nijmegen/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/devops-nijmegen/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/devops-nijmegen/subscriptions',
#      'organizations_url': 'https://api.github.com/users/devops-nijmegen/orgs',
#      'repos_url': 'https://api.github.com/users/devops-nijmegen/repos',
#      'events_url': 'https://api.github.com/users/devops-nijmegen/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/devops-nijmegen/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Upgrades project dependencies. See details in [workflow run].\n\n[Workflow Run]: https://github.com/GemeenteNijmegen/yivi-issue-server/actions/runs/6686610338\n\n------\n\n*Automatically created by projen via the "upgrade-acceptance" workflow*',
#     'created_at': '2023-10-30T00:09:52Z',
#     'updated_at': '2023-10-30T00:10:04Z',
#     'closed_at': '2023-10-30T00:10:04Z',
#     'merged_at': '2023-10-30T00:10:04Z',
#     'merge_commit_sha': 'cf0f5561cd22ce3ac51fb1e27a7816f03ca46fbd',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 5653413493,
#       'node_id': 'LA_kwDOJPlmB88AAAABUPg-dQ',
#       'url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/labels/auto-merge',
#       'name': 'auto-merge',
#       'color': 'ededed',
#       'default': False,
#       'description': None}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/pulls/163/commits',
#     'review_comments_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/pulls/163/comments',
#     'review_comment_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/issues/163/comments',
#     'statuses_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/statuses/852aaa60b58227945429a3811e3335212dbc9114',
#     'head': {'label': 'GemeenteNijmegen:github-actions/upgrade-acceptance',
#      'ref': 'github-actions/upgrade-acceptance',
#      'sha': '852aaa60b58227945429a3811e3335212dbc9114',
#      'user': {'login': 'GemeenteNijmegen',
#       'id': 29945117,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI5OTQ1MTE3',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/29945117?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/GemeenteNijmegen',
#       'html_url': 'https://github.com/GemeenteNijmegen',
#       'followers_url': 'https://api.github.com/users/GemeenteNijmegen/followers',
#       'following_url': 'https://api.github.com/users/GemeenteNijmegen/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/GemeenteNijmegen/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/GemeenteNijmegen/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/GemeenteNijmegen/subscriptions',
#       'organizations_url': 'https://api.github.com/users/GemeenteNijmegen/orgs',
#       'repos_url': 'https://api.github.com/users/GemeenteNijmegen/repos',
#       'events_url': 'https://api.github.com/users/GemeenteNijmegen/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/GemeenteNijmegen/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 620324359,
#       'node_id': 'R_kgDOJPlmBw',
#       'name': 'yivi-issue-server',
#       'full_name': 'GemeenteNijmegen/yivi-issue-server',
#       'private': False,
#       'owner': {'login': 'GemeenteNijmegen',
#        'id': 29945117,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI5OTQ1MTE3',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/29945117?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/GemeenteNijmegen',
#        'html_url': 'https://github.com/GemeenteNijmegen',
#        'followers_url': 'https://api.github.com/users/GemeenteNijmegen/followers',
#        'following_url': 'https://api.github.com/users/GemeenteNijmegen/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/GemeenteNijmegen/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/GemeenteNijmegen/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/GemeenteNijmegen/subscriptions',
#        'organizations_url': 'https://api.github.com/users/GemeenteNijmegen/orgs',
#        'repos_url': 'https://api.github.com/users/GemeenteNijmegen/repos',
#        'events_url': 'https://api.github.com/users/GemeenteNijmegen/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/GemeenteNijmegen/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/GemeenteNijmegen/yivi-issue-server',
#       'description': 'Infrastucture as Code for hosting our Yivi issue server',
#       'fork': False,
#       'url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server',
#       'forks_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/forks',
#       'keys_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/teams',
#       'hooks_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/hooks',
#       'issue_events_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/events',
#       'assignees_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/tags',
#       'blobs_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/languages',
#       'stargazers_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/stargazers',
#       'contributors_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/contributors',
#       'subscribers_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/subscribers',
#       'subscription_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/subscription',
#       'commits_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/merges',
#       'archive_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/downloads',
#       'issues_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/deployments',
#       'created_at': '2023-03-28T13:11:47Z',
#       'updated_at': '2023-03-28T13:12:16Z',
#       'pushed_at': '2023-10-30T00:10:04Z',
#       'git_url': 'git://github.com/GemeenteNijmegen/yivi-issue-server.git',
#       'ssh_url': 'git@github.com:GemeenteNijmegen/yivi-issue-server.git',
#       'clone_url': 'https://github.com/GemeenteNijmegen/yivi-issue-server.git',
#       'svn_url': 'https://github.com/GemeenteNijmegen/yivi-issue-server',
#       'homepage': None,
#       'size': 2553,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 6,
#       'license': {'key': 'eupl-1.2',
#        'name': 'European Union Public License 1.2',
#        'spdx_id': 'EUPL-1.2',
#        'url': 'https://api.github.com/licenses/eupl-1.2',
#        'node_id': 'MDc6TGljZW5zZTM0'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 6,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'GemeenteNijmegen:acceptance',
#      'ref': 'acceptance',
#      'sha': '7edb71683988c44ec80ae82c70d6104e88783fce',
#      'user': {'login': 'GemeenteNijmegen',
#       'id': 29945117,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI5OTQ1MTE3',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/29945117?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/GemeenteNijmegen',
#       'html_url': 'https://github.com/GemeenteNijmegen',
#       'followers_url': 'https://api.github.com/users/GemeenteNijmegen/followers',
#       'following_url': 'https://api.github.com/users/GemeenteNijmegen/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/GemeenteNijmegen/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/GemeenteNijmegen/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/GemeenteNijmegen/subscriptions',
#       'organizations_url': 'https://api.github.com/users/GemeenteNijmegen/orgs',
#       'repos_url': 'https://api.github.com/users/GemeenteNijmegen/repos',
#       'events_url': 'https://api.github.com/users/GemeenteNijmegen/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/GemeenteNijmegen/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 620324359,
#       'node_id': 'R_kgDOJPlmBw',
#       'name': 'yivi-issue-server',
#       'full_name': 'GemeenteNijmegen/yivi-issue-server',
#       'private': False,
#       'owner': {'login': 'GemeenteNijmegen',
#        'id': 29945117,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI5OTQ1MTE3',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/29945117?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/GemeenteNijmegen',
#        'html_url': 'https://github.com/GemeenteNijmegen',
#        'followers_url': 'https://api.github.com/users/GemeenteNijmegen/followers',
#        'following_url': 'https://api.github.com/users/GemeenteNijmegen/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/GemeenteNijmegen/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/GemeenteNijmegen/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/GemeenteNijmegen/subscriptions',
#        'organizations_url': 'https://api.github.com/users/GemeenteNijmegen/orgs',
#        'repos_url': 'https://api.github.com/users/GemeenteNijmegen/repos',
#        'events_url': 'https://api.github.com/users/GemeenteNijmegen/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/GemeenteNijmegen/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/GemeenteNijmegen/yivi-issue-server',
#       'description': 'Infrastucture as Code for hosting our Yivi issue server',
#       'fork': False,
#       'url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server',
#       'forks_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/forks',
#       'keys_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/teams',
#       'hooks_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/hooks',
#       'issue_events_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/events',
#       'assignees_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/tags',
#       'blobs_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/languages',
#       'stargazers_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/stargazers',
#       'contributors_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/contributors',
#       'subscribers_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/subscribers',
#       'subscription_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/subscription',
#       'commits_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/GemeenteNijmegen/yivi-issue-server/git/commits{/sha}',
# ...
#        'received_events_url': 'https://api.github.com/users/bk00119/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/bk00119/BEKK',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/bk00119/BEKK',
#       'forks_url': 'https://api.github.com/repos/bk00119/BEKK/forks',
#       'keys_url': 'https://api.github.com/repos/bk00119/BEKK/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/bk00119/BEKK/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/bk00119/BEKK/teams',
#       'hooks_url': 'https://api.github.com/repos/bk00119/BEKK/hooks',
#       'issue_events_url': 'https://api.github.com/repos/bk00119/BEKK/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/bk00119/BEKK/events',
#       'assignees_url': 'https://api.github.com/repos/bk00119/BEKK/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/bk00119/BEKK/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/bk00119/BEKK/tags',
#       'blobs_url': 'https://api.github.com/repos/bk00119/BEKK/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/bk00119/BEKK/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/bk00119/BEKK/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/bk00119/BEKK/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/bk00119/BEKK/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/bk00119/BEKK/languages',
#       'stargazers_url': 'https://api.github.com/repos/bk00119/BEKK/stargazers',
#       'contributors_url': 'https://api.github.com/repos/bk00119/BEKK/contributors',
#       'subscribers_url': 'https://api.github.com/repos/bk00119/BEKK/subscribers',
#       'subscription_url': 'https://api.github.com/repos/bk00119/BEKK/subscription',
#       'commits_url': 'https://api.github.com/repos/bk00119/BEKK/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/bk00119/BEKK/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/bk00119/BEKK/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/bk00119/BEKK/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/bk00119/BEKK/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/bk00119/BEKK/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/bk00119/BEKK/merges',
#       'archive_url': 'https://api.github.com/repos/bk00119/BEKK/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/bk00119/BEKK/downloads',
#       'issues_url': 'https://api.github.com/repos/bk00119/BEKK/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/bk00119/BEKK/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/bk00119/BEKK/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/bk00119/BEKK/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/bk00119/BEKK/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/bk00119/BEKK/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/bk00119/BEKK/deployments',
#       'created_at': '2023-09-21T15:59:50Z',
#       'updated_at': '2023-09-21T16:25:18Z',
#       'pushed_at': '2023-10-29T23:41:51Z',
#       'git_url': 'git://github.com/bk00119/BEKK.git',
#       'ssh_url': 'git@github.com:bk00119/BEKK.git',
#       'clone_url': 'https://github.com/bk00119/BEKK.git',
#       'svn_url': 'https://github.com/bk00119/BEKK',
#       'homepage': None,
#       'size': 3512,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 3,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'gpl-3.0',
#        'name': 'GNU General Public License v3.0',
#        'spdx_id': 'GPL-3.0',
#        'url': 'https://api.github.com/licenses/gpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTk='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 3,
#       'open_issues': 1,
#       'watchers': 1,
#       'default_branch': 'master'}},
#     'base': {'label': 'estherwng:master',
#      'ref': 'master',
#      'sha': 'c715d9d74f27a844214b371f3412de52c569f655',
#      'user': {'login': 'estherwng',
#       'id': 70925047,
#       'node_id': 'MDQ6VXNlcjcwOTI1MDQ3',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/70925047?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/estherwng',
#       'html_url': 'https://github.com/estherwng',
#       'followers_url': 'https://api.github.com/users/estherwng/followers',
#       'following_url': 'https://api.github.com/users/estherwng/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/estherwng/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/estherwng/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/estherwng/subscriptions',
#       'organizations_url': 'https://api.github.com/users/estherwng/orgs',
#       'repos_url': 'https://api.github.com/users/estherwng/repos',
#       'events_url': 'https://api.github.com/users/estherwng/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/estherwng/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 710906202,
#       'node_id': 'R_kgDOKl-RWg',
#       'name': 'BEKK',
#       'full_name': 'estherwng/BEKK',
#       'private': False,
#       'owner': {'login': 'estherwng',
#        'id': 70925047,
#        'node_id': 'MDQ6VXNlcjcwOTI1MDQ3',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/70925047?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/estherwng',
#        'html_url': 'https://github.com/estherwng',
#        'followers_url': 'https://api.github.com/users/estherwng/followers',
#        'following_url': 'https://api.github.com/users/estherwng/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/estherwng/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/estherwng/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/estherwng/subscriptions',
#        'organizations_url': 'https://api.github.com/users/estherwng/orgs',
#        'repos_url': 'https://api.github.com/users/estherwng/repos',
#        'events_url': 'https://api.github.com/users/estherwng/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/estherwng/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/estherwng/BEKK',
#       'description': None,
#       'fork': True,
#       'url': 'https://api.github.com/repos/estherwng/BEKK',
#       'forks_url': 'https://api.github.com/repos/estherwng/BEKK/forks',
#       'keys_url': 'https://api.github.com/repos/estherwng/BEKK/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/estherwng/BEKK/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/estherwng/BEKK/teams',
#       'hooks_url': 'https://api.github.com/repos/estherwng/BEKK/hooks',
#       'issue_events_url': 'https://api.github.com/repos/estherwng/BEKK/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/estherwng/BEKK/events',
#       'assignees_url': 'https://api.github.com/repos/estherwng/BEKK/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/estherwng/BEKK/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/estherwng/BEKK/tags',
#       'blobs_url': 'https://api.github.com/repos/estherwng/BEKK/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/estherwng/BEKK/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/estherwng/BEKK/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/estherwng/BEKK/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/estherwng/BEKK/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/estherwng/BEKK/languages',
#       'stargazers_url': 'https://api.github.com/repos/estherwng/BEKK/stargazers',
#       'contributors_url': 'https://api.github.com/repos/estherwng/BEKK/contributors',
#       'subscribers_url': 'https://api.github.com/repos/estherwng/BEKK/subscribers',
#       'subscription_url': 'https://api.github.com/repos/estherwng/BEKK/subscription',
#       'commits_url': 'https://api.github.com/repos/estherwng/BEKK/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/estherwng/BEKK/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/estherwng/BEKK/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/estherwng/BEKK/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/estherwng/BEKK/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/estherwng/BEKK/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/estherwng/BEKK/merges',
#       'archive_url': 'https://api.github.com/repos/estherwng/BEKK/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/estherwng/BEKK/downloads',
#       'issues_url': 'https://api.github.com/repos/estherwng/BEKK/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/estherwng/BEKK/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/estherwng/BEKK/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/estherwng/BEKK/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/estherwng/BEKK/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/estherwng/BEKK/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/estherwng/BEKK/deployments',
#       'created_at': '2023-10-27T17:38:35Z',
#       'updated_at': '2023-10-27T17:38:35Z',
#       'pushed_at': '2023-10-30T00:10:04Z',
#       'git_url': 'git://github.com/estherwng/BEKK.git',
#       'ssh_url': 'git@github.com:estherwng/BEKK.git',
#       'clone_url': 'https://github.com/estherwng/BEKK.git',
#       'svn_url': 'https://github.com/estherwng/BEKK',
#       'homepage': None,
#       'size': 3541,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'gpl-3.0',
#        'name': 'GNU General Public License v3.0',
#        'spdx_id': 'GPL-3.0',
#        'url': 'https://api.github.com/licenses/gpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTk='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/estherwng/BEKK/pulls/1'},
#      'html': {'href': 'https://github.com/estherwng/BEKK/pull/1'},
#      'issue': {'href': 'https://api.github.com/repos/estherwng/BEKK/issues/1'},
#      'comments': {'href': 'https://api.github.com/repos/estherwng/BEKK/issues/1/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/estherwng/BEKK/pulls/1/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/estherwng/BEKK/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/estherwng/BEKK/pulls/1/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/estherwng/BEKK/statuses/336918f20865c784cdd0321a36dabd765e92c4ee'}},
#     'author_association': 'OWNER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': True,
#     'commits': 10,
#     'additions': 143,
#     'deletions': 55,
#     'changed_files': 11}},
#   'public': True,
#   'created_at': '2023-10-30T00:10:05Z'},
#  {'id': '32933169716',
#   'type': 'CreateEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 590979097,
#    'name': 'vasttrafik/trivy-db2',
#    'url': 'https://api.github.com/repos/vasttrafik/trivy-db2'},
#   'payload': {'ref': 'v1.0.285',
#    'ref_type': 'tag',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-10-30T00:10:04Z',
#   'org': {'id': 14925059,
#    'login': 'vasttrafik',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/vasttrafik',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14925059?'}},
#  {'id': '32933169709',
#   'type': 'PushEvent',
#   'actor': {'id': 140762345,
#    'login': 'walkerjohnelle',
#    'display_login': 'walkerjohnelle',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/walkerjohnelle',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/140762345?'},
#   'repo': {'id': 711663478,
#    'name': 'walkerjohnelle/SDPre',
#    'url': 'https://api.github.com/repos/walkerjohnelle/SDPre'},
#   'payload': {'repository_id': 711663478,
#    'push_id': 15612675414,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '24bb0f3f14601b2a2aa47454879c27850c5962a3',
#    'before': 'd89ebfc863b92524a9b41c5a14f53cf52622ffe5',
#    'commits': [{'sha': '24bb0f3f14601b2a2aa47454879c27850c5962a3',
#      'author': {'email': 'johnellewalker@gmail.com',
#       'name': 'Johnelle Walker'},
#      'message': 'complete Objective2 Labs 1, 2, & 3',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/walkerjohnelle/SDPre/commits/24bb0f3f14601b2a2aa47454879c27850c5962a3'}]},
#   'public': True,
#   'created_at': '2023-10-30T00:10:04Z'},
#  {'id': '32933169720',
#   'type': 'DeleteEvent',
#   'actor': {'id': 29860510,
#    'login': 'cw-sakamoto',
#    'display_login': 'cw-sakamoto',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cw-sakamoto',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29860510?'},
#   'repo': {'id': 101840988,
#    'name': 'chatwork/dockerfiles',
#    'url': 'https://api.github.com/repos/chatwork/dockerfiles'},
#   'payload': {'ref': 'mod-up-argocd-helmfile-20231028230244',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-10-30T00:10:05Z',
#   'org': {'id': 1772738,
#    'login': 'chatwork',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/chatwork',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1772738?'}},
#  {'id': '32933169725',
#   'type': 'CreateEvent',
#   'actor': {'id': 36490558,
#    'login': 'regro-cf-autotick-bot',
#    'display_login': 'regro-cf-autotick-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/regro-cf-autotick-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36490558?'},
#   'repo': {'id': 711656082,
#    'name': 'regro-cf-autotick-bot/checkov-feedstock',
#    'url': 'https://api.github.com/repos/regro-cf-autotick-bot/checkov-feedstock'},
#   'payload': {'ref': '3.0.13_he1a2d0',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'A conda-smithy repository for checkov.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-10-30T00:10:05Z'}]

# %% [markdown]
# # Utilizando outro endpoint

# %%
r = requests.get('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']

# %%
# especificando a versão da API
headers = {'X-GitHub-Api-Version': '2022-11-28'}

# %%
r = requests.get('https://api.github.com/events', headers=headers)
r.status_code
# Out:
# 200
